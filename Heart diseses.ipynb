# %% [markdown]
# IMPORTING LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
IMPORTING DATA

# %%
Data=pd.read_csv("https://raw.githubusercontent.com/DataThinkers/Datasets/main/DS/heart.csv")

# %%
print(Data)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# DISPLAYING FIRST 5 ROWS

# %%
Data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# 1.Age
# 2.Sex
# 3.Chest pain type(4 values)
# value(0)-typical angina
# value(1)-atypical angina
# value(2)-non-anginal
# value(3)-asymptomatic
# 4.trestbps:resting blood pressure (in mm hg at admission to the hospital)
# 5.chol:serum cholestrol in mg/dl
# 6.fbs:fasting blood sugar(>120mg/dl)(1=true,0=false)
# 7.restecg:rest electrocardiographic results:
# value(0)-normal
# value(1)-having ST-T wave abnormality(T wave inversions and/or ST elevation or depression of >0.05mV)
# value(2)-showing probabble or left ventricular hypertrophy as Este's criteria
# 8.thalach:maximum heart rate achieved
# 9.exang:exercise induced angina
# 10.oldpeak:ST induced depression indused by angina
# 11.slope:the slope of peak exersice ST segment:
# value(0)-upsloping
# value(1)-flat
# value(2)-downsloping
# 12.ca:number of major vessels (0-3)
# 13.thal:3=normal,6=fixed defect,7=reversible defect
# 14.target:0=less chances of heart attack,1= more chances of heart attack

# %% [markdown]
# DISPLAYING LAST 5 ROWS

# %%
Data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# SHAPE OF DATASET

# %%
Data.shape
# Out:
# (1025, 14)

# %%
print("Number of rows:",Data.shape[0])
print("Number of columns:",Data.shape[1])
# Out:
# Number of rows: 1025
# Number of columns: 14

# %% [markdown]
# INFORMATION ABOUT OUR DATASET:TOTAL NUMBER OF ROWS, TOTAL NUMBER OF COLUMNS ,DATATYPE OF EACH COLUMN AND MEMORY REQUIRED

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# NULL VALUES IN DATASET

# %%
Data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# DUPLICATE VALUES IN DATASET

# %%
data_duplicate=Data.duplicated().any()
print(data_duplicate)
# Out:
# True

# %% [markdown]
# REMOVING DUPLICATE VALUES FROM THE DATASET

# %%
Data=Data.drop_duplicates()

# %%
Data.shape
# Out:
# (302, 14)

# %% [markdown]
# STATISTICS OF THE DATASET

# %%
Data.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# CORRELATION MATRIX

# %%
Data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thal      0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# ...

# %%
plt.figure(figsize=(17,6))
sns.heatmap(Data.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# PEOPLE HAVING AND NOT HAVING HEART DISEASE

# %%
Data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
Data['target'].value_counts()
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %% [markdown]
# COCLUSION: 164 people out of total have heart disease and 138 out of total does not have any.

# %% [markdown]
# WHICH SEX IS MORE PRONE TO HEART DISEASES

# %%
Data['sex'].value_counts()
# Out:
# sex
# 1    713
# 0    312
# Name: count, dtype: int64

# %% [markdown]
# CONCLUSION: 206 males and 96 females have heart disesase.

# %% [markdown]
# GENDER DISTRIBUTION ACCORDING TO TARGET VALUES

# %%
Data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.countplot(x='sex',hue='target',data=Data)
plt.xticks([0,1],['Female','Male'])
plt.legend(labels=['non-diseased','diseased'])
plt.show()

# %% [markdown]
# CONCLUSION: Diseased females are more in number as compared to healthy females and diseased males are lesser in number as compared to healthy males

# %% [markdown]
# AGE DISTRIBUTION IN THE DATASET

# %%
sns.distplot(Data['age'],bins=20)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_5920\827257274.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Data['age'],bins=20)

# %% [markdown]
# CONCLUSION:Maximun number of diseased people are in their 60's

# %% [markdown]
# CHEST PAIN TYPE
# 4 Values:
# 0=typical angina
# 1=atypical angina
# 2=non-anginal pain
# 3=asymptomatic

# %% [markdown]
# CHEST PAIN DISTRIBUTION AS PER TARGET VARIABLE

# %%
Data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.countplot(x='cp',hue='target',data=Data)
plt.legend(labels=['non-diseased','diseased'])
plt.show()

# %% [markdown]
# CONCLUSION: 1.Out of all the people having typical angina, number of non diseased individuals are more than diseased.
# 2.Out of all the people having atypical angina, number of non-diseased individuals is lesser than diseased.
# 3.Out of all the People having non-anginal pain, number of non-diseased individuals are lesser than diseased.
# 4.Out of all the people who are asymptomatic to any heart disesase, number of non-diseased are lesser than diseased.
# * Out of all non-diseased people, number of people having typical angina is maximum and people who are asymptomatic to any heart disease is minimum.
# * Out of all diseased people,number of people having non-anginal pain is maximum and people who are asymptomatic is minimum .

# %% [markdown]
# FASTING BLOOD SUGAR DISTRIBUTION AS PER TARGET VARIABLE

# %%
sns.countplot(x='fbs',hue='target',data=Data)
plt.legend(labels=['non-diseased','diseased'])
plt.show()

# %% [markdown]
# CONCLUSION:Maximum number of diseased individuals are dibetic.

# %% [markdown]
# RESTING BLOOD PRESSURE DISTRIBUTION

# %%
Data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
Data['trestbps'].hist()
# Out:
# <Axes: >

# %% [markdown]
#  CONCLUSION : Maximum nummber of diseased individuals have their resting blood pressure between 120 t

# %% [markdown]
# RESTING BLOOD PRESSURE AS PER SEX COLUMN

# %%
x=sns.FacetGrid(Data,hue="sex",aspect=4)
x.map(sns.kdeplot,'trestbps',shade=True)
plt.legend(labels=['Male','Female'])
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# CONCLUSION:Diseased males have higher resting blood pressure than diseased females.

# %% [markdown]
# DISTRIBUTION OF SERUM CHOLESTROL

# %%
Data['chol'].hist()
# Out:
# <Axes: >

# %% [markdown]
# CONCLUSION: Most of the diseased people have their serum cholestrol levels between 200-300 mg/dl.
